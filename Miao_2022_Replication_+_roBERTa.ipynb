# %% [markdown]
# **Remember to change runtime to GPU**
#
# Original code repo: https://github.com/mzx4936/GF-OLD
#
# Original data repo: https://github.com/mzx4936/GF-OLD-Dataset
#
#
# Cloned code repo: https://github.com/guptaviha/GF-OLD
#
# Cloned data repo: https://github.com/guptaviha/GF-OLD-Dataset

# %%
# install dependencies
# Might have to restart runtime after this
# !pip install dgl-cu116 dglgo -f https://data.dgl.ai/wheels/repo.html
# Out:
# Looking in links: https://data.dgl.ai/wheels/repo.html
# ...
#      |████████████████████████████████| 246.3 MB 8.1 kB/s eta 0:00:0101 |▊                               | 5.5 MB 846 kB/s eta 0:04:45
# ...
#      |████████████████████████████████| 63 kB 3.2 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 280 kB 19.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 78 kB 13.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.0 MB 56.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 33.8 MB 93.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 29.3 MB 31.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 9.5 MB 81.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 78 kB 18.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 45 kB 7.5 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 109 kB 107.0 MB/s eta 0:00:01
# ...

# %%
# install remaining dependencies
# !pip install emoji
# !pip install wordsegment
# !pip install ekphrasis
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 240 kB 9.0 MB/s eta 0:00:01
# ...
#   Created wheel for emoji: filename=emoji-2.2.0-py3-none-any.whl size=234912 sha256=d5913c72fdfa00fe5c54651d4d5db8adcc268fab5af1d706df835ddbd801fb0e
#   Stored in directory: /home/studio-lab-user/.cache/pip/wheels/9a/b8/0f/f580817231cbf59f6ade9fd132ff60ada1de9f7dc85521f857
# Successfully built emoji
# ...
#      |████████████████████████████████| 4.8 MB 9.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 83 kB 3.5 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 52 kB 2.8 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 53 kB 4.2 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 1.5 MB 79.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 769 kB 102.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 5.8 MB 10.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 182 kB 114.1 MB/s eta 0:00:01
# ...

# %%
# start training
# !python train_joint.py \
  -bs=32 \
  -lr_other=5e-5 \
  -lr_gat=1e-2 \
  -ep=20 \
  -dr=0.5 \
  -ad=0.1 \
  -hs=768 \
  --model=roberta \
  --clip \
  --cuda=1
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/ekphrasis/classes/tokenizer.py:225: FutureWarning: Possible nested set at position 2190
#   self.tok = re.compile(r"({})".format("|".join(pipeline)))
# Word statistics files not found!
# Downloading... done!
# Unpacking... done!
# Reading twitter - 1grams ...
# generating cache file for faster loading...
# reading ngrams /home/studio-lab-user/.ekphrasis/stats/twitter/counts_1grams.txt
# Reading twitter - 2grams ...
# generating cache file for faster loading...
# reading ngrams /home/studio-lab-user/.ekphrasis/stats/twitter/counts_2grams.txt
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/ekphrasis/classes/exmanager.py:14: FutureWarning: Possible nested set at position 42
#   regexes = {k.lower(): re.compile(self.expressions[k]) for k, v in
# Reading twitter - 1grams ...
# DGL backend not selected or invalid.  Assuming PyTorch for now.
# ...

# %%
# !python train_joint.py \
#   -bs=64 \
#   -lr_other=5e-5 \
#   -lr_gat=1e-2 \
#   -ep=20 \
#   -dr=0.5 \
#   -ad=0.1 \
#   -hs=768 \
#   --model=jointv2 \
#   --clip \
#   --cuda=1
