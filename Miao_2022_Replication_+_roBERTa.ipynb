# %%
# install dependencies
# !pip install dgl-cu116 dglgo -f https://data.dgl.ai/wheels/repo.html
# !pip install emoji
# !pip install wordsegment
# !pip install ekphrasis
# !pip install transformers
# Out:
# Looking in links: https://data.dgl.ai/wheels/repo.html
# Requirement already satisfied: dgl-cu116 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (0.9.1.post1)
# Requirement already satisfied: dglgo in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (0.0.2)
# Requirement already satisfied: networkx>=2.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from dgl-cu116) (2.8.8)
# Requirement already satisfied: requests>=2.19.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from dgl-cu116) (2.28.1)
# Requirement already satisfied: numpy>=1.14.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from dgl-cu116) (1.23.4)
# Requirement already satisfied: psutil>=5.8.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from dgl-cu116) (5.9.4)
# Requirement already satisfied: tqdm in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from dgl-cu116) (4.64.1)
# Requirement already satisfied: scipy>=1.1.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from dgl-cu116) (1.9.3)
# Requirement already satisfied: numpydoc>=1.1.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from dglgo) (1.5.0)
# Requirement already satisfied: typer>=0.4.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from dglgo) (0.7.0)
# Requirement already satisfied: ogb>=1.3.3 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from dglgo) (1.3.5)
# Requirement already satisfied: PyYAML>=5.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from dglgo) (6.0)
# Requirement already satisfied: isort>=5.10.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from dglgo) (5.10.1)
# Requirement already satisfied: pydantic>=1.9.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from dglgo) (1.10.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from dglgo) (1.2.0)
# Requirement already satisfied: ruamel.yaml>=0.17.20 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from dglgo) (0.17.21)
# Requirement already satisfied: rdkit-pypi in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from dglgo) (2022.9.2)
# Requirement already satisfied: autopep8>=1.6.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from dglgo) (2.0.0)
# Requirement already satisfied: tomli in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from autopep8>=1.6.0->dglgo) (2.0.1)
# Requirement already satisfied: pycodestyle>=2.9.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from autopep8>=1.6.0->dglgo) (2.10.0)
# Requirement already satisfied: sphinx>=4.2 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from numpydoc>=1.1.0->dglgo) (5.3.0)
# Requirement already satisfied: Jinja2>=2.10 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from numpydoc>=1.1.0->dglgo) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from Jinja2>=2.10->numpydoc>=1.1.0->dglgo) (2.1.1)
# Requirement already satisfied: six>=1.12.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from ogb>=1.3.3->dglgo) (1.16.0)
# Requirement already satisfied: urllib3>=1.24.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from ogb>=1.3.3->dglgo) (1.26.12)
# Requirement already satisfied: outdated>=0.2.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from ogb>=1.3.3->dglgo) (0.2.2)
# Requirement already satisfied: torch>=1.6.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from ogb>=1.3.3->dglgo) (1.13.0)
# Requirement already satisfied: pandas>=0.24.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from ogb>=1.3.3->dglgo) (1.5.2)
# Requirement already satisfied: littleutils in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from outdated>=0.2.0->ogb>=1.3.3->dglgo) (0.2.2)
# Requirement already satisfied: setuptools>=44 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from outdated>=0.2.0->ogb>=1.3.3->dglgo) (65.5.0)
# Requirement already satisfied: pytz>=2020.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from pandas>=0.24.0->ogb>=1.3.3->dglgo) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from pandas>=0.24.0->ogb>=1.3.3->dglgo) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from pydantic>=1.9.0->dglgo) (4.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests>=2.19.0->dgl-cu116) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests>=2.19.0->dgl-cu116) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests>=2.19.0->dgl-cu116) (2.1.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from ruamel.yaml>=0.17.20->dglgo) (0.2.7)
# Requirement already satisfied: joblib>=1.1.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from scikit-learn>=0.20.0->dglgo) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from scikit-learn>=0.20.0->dglgo) (3.1.0)
# Requirement already satisfied: sphinxcontrib-devhelp in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (1.0.2)
# Requirement already satisfied: sphinxcontrib-applehelp in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (1.0.2)
# Requirement already satisfied: Pygments>=2.12 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (2.13.0)
# Requirement already satisfied: sphinxcontrib-jsmath in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (1.0.1)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (1.1.5)
# Requirement already satisfied: importlib-metadata>=4.8 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (4.11.4)
# Requirement already satisfied: sphinxcontrib-qthelp in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (1.0.3)
# Requirement already satisfied: snowballstemmer>=2.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (2.2.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (2.0.0)
# Requirement already satisfied: docutils<0.20,>=0.14 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (0.19)
# Requirement already satisfied: imagesize>=1.3 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (1.4.1)
# Requirement already satisfied: packaging>=21.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (21.3)
# Requirement already satisfied: babel>=2.9 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (2.11.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from sphinx>=4.2->numpydoc>=1.1.0->dglgo) (0.7.12)
# Requirement already satisfied: zipp>=0.5 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from importlib-metadata>=4.8->sphinx>=4.2->numpydoc>=1.1.0->dglgo) (3.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from packaging>=21.0->sphinx>=4.2->numpydoc>=1.1.0->dglgo) (3.0.9)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (11.10.3.66)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from torch>=1.6.0->ogb>=1.3.3->dglgo) (11.7.99)
# Requirement already satisfied: wheel in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->ogb>=1.3.3->dglgo) (0.37.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from typer>=0.4.0->dglgo) (8.1.3)
# Requirement already satisfied: Pillow in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from rdkit-pypi->dglgo) (9.3.0)
# Requirement already satisfied: emoji in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (2.2.0)
# Requirement already satisfied: wordsegment in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (1.3.1)
# Requirement already satisfied: ekphrasis in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (0.5.4)
# Requirement already satisfied: colorama in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from ekphrasis) (0.4.6)
# Requirement already satisfied: termcolor in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from ekphrasis) (2.1.1)
# Requirement already satisfied: matplotlib in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from ekphrasis) (3.6.2)
# Requirement already satisfied: ujson in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from ekphrasis) (5.6.0)
# Requirement already satisfied: ftfy in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from ekphrasis) (6.1.1)
# Requirement already satisfied: tqdm in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from ekphrasis) (4.64.1)
# Requirement already satisfied: numpy in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from ekphrasis) (1.23.4)
# Requirement already satisfied: nltk in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from ekphrasis) (3.7)
# Requirement already satisfied: wcwidth>=0.2.5 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from ftfy->ekphrasis) (0.2.5)
# Requirement already satisfied: pillow>=6.2.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib->ekphrasis) (9.3.0)
# Requirement already satisfied: packaging>=20.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib->ekphrasis) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib->ekphrasis) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib->ekphrasis) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib->ekphrasis) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib->ekphrasis) (1.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib->ekphrasis) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from matplotlib->ekphrasis) (0.11.0)
# Requirement already satisfied: six>=1.5 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->ekphrasis) (1.16.0)
# Requirement already satisfied: click in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from nltk->ekphrasis) (8.1.3)
# Requirement already satisfied: joblib in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from nltk->ekphrasis) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from nltk->ekphrasis) (2022.10.31)
# Requirement already satisfied: transformers in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (4.25.1)
# Requirement already satisfied: packaging>=20.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers) (21.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers) (0.11.1)
# Requirement already satisfied: requests in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers) (2.28.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers) (0.13.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers) (2022.10.31)
# Requirement already satisfied: pyyaml>=5.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers) (3.8.2)
# Requirement already satisfied: tqdm>=4.27 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers) (4.64.1)
# Requirement already satisfied: numpy>=1.17 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers) (1.23.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->transformers) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->transformers) (1.26.12)

# %%
# start training
# !python train_joint.py \
  -bs=32 \
  -lr_other=5e-5 \
  -lr_gat=1e-2 \
  -ep=20 \
  -dr=0.5 \
  -ad=0.1 \
  -hs=768 \
  --model=joint_roberta \
  --clip \
  --cuda=1
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/ekphrasis/classes/tokenizer.py:225: FutureWarning: Possible nested set at position 2190
#   self.tok = re.compile(r"({})".format("|".join(pipeline)))
# Reading twitter - 1grams ...
# Reading twitter - 2grams ...
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/ekphrasis/classes/exmanager.py:14: FutureWarning: Possible nested set at position 42
#   regexes = {k.lower(): re.compile(self.expressions[k]) for k, v in
# Reading twitter - 1grams ...
# torch.cuda.is_available() True
# device is cuda
# Graph(num_nodes=1260, num_edges=10137,
#       ndata_schemes={'features': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# model_name joint_roberta
# model.gat.parameters() <generator object Module.parameters at 0x7fc651755f90>
# layer [140491185617072, 140491185617552, 140491185616032, 140491185616592, 140491185616272, 140491185617792, 140491185616112]
# model.parameters() <generator object Module.parameters at 0x7fc651755f90>
# base_params <filter object at 0x7fc6a7389130>
# HELLOOOOOOOOOO
# Epoch 0
# ====================
# Training:   0%|                                         | 0/280 [00:00<?, ?it/s]embs torch.Size([32, 218, 768])
# features torch.Size([32, 9, 768])
# embs torch.Size([32, 227, 768])
# x torch.Size([1, 207, 768])
# Training:   0%|                                         | 0/280 [00:01<?, ?it/s]
# Traceback (most recent call last):
#   File "/home/studio-lab-user/sagemaker-studiolab-notebooks/GF-OLD/train_joint.py", line 183, in <module>
#     trainer.train()
#   File "/home/studio-lab-user/sagemaker-studiolab-notebooks/GF-OLD/trainer_joint.py", line 94, in train
#     self.train_one_epoch()
#   File "/home/studio-lab-user/sagemaker-studiolab-notebooks/GF-OLD/trainer_joint.py", line 142, in train_one_epoch
#     logits = self.model(inputs, lens, mask, labels, self.g, self.features, url, self.device)
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1190, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/studio-lab-user/sagemaker-studiolab-notebooks/GF-OLD/models/joint.py", line 131, in forward
#     h = self.bert(inputs, lens, mask, labels, gat_emb)
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1190, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/studio-lab-user/sagemaker-studiolab-notebooks/GF-OLD/models/joint.py", line 214, in forward
#     embs = self.layer_norm(embs + x)
# RuntimeError: The size of tensor a (227) must match the size of tensor b (207) at non-singleton dimension 1

# %%
# !python train_joint.py \
  -bs=32 \
  -lr_other=5e-5 \
  -lr_gat=1e-2 \
  -ep=20 \
  -dr=0.5 \
  -ad=0.1 \
  -hs=768 \
  --model=joint \
  --clip \
  --cuda=1
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/ekphrasis/classes/tokenizer.py:225: FutureWarning: Possible nested set at position 2190
#   self.tok = re.compile(r"({})".format("|".join(pipeline)))
# Reading twitter - 1grams ...
# Reading twitter - 2grams ...
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/ekphrasis/classes/exmanager.py:14: FutureWarning: Possible nested set at position 42
#   regexes = {k.lower(): re.compile(self.expressions[k]) for k, v in
# Reading twitter - 1grams ...
# torch.cuda.is_available() True
# device is cuda
# Graph(num_nodes=1260, num_edges=10137,
#       ndata_schemes={'features': Scheme(shape=(2,), dtype=torch.float32)}
#       edata_schemes={})
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# model_name joint
# model.gat.parameters() <generator object Module.parameters at 0x7f2aeefa87b0>
# layer [139822438558912, 139822438557472, 139822438557312, 139822438557552, 139822438558272, 139822438559152, 139822438557392]
# model.parameters() <generator object Module.parameters at 0x7f2aeefa87b0>
# base_params <filter object at 0x7f2af2b52490>
# HELLOOOOOOOOOO
# Epoch 0
# ====================
# Training:   0%|                                         | 0/280 [00:00<?, ?it/s]embs torch.Size([32, 110, 768])
# features torch.Size([32, 9, 768])
# embs torch.Size([32, 119, 768])
# x torch.Size([1, 119, 768])
# Training:   0%|                                 | 1/280 [00:01<07:34,  1.63s/it]embs torch.Size([32, 110, 768])
# features torch.Size([32, 9, 768])
# embs torch.Size([32, 119, 768])
# x torch.Size([1, 119, 768])
# Training:   1%|▏                                | 2/280 [00:02<04:31,  1.02it/s]embs torch.Size([32, 110, 768])
# features torch.Size([32, 9, 768])
# embs torch.Size([32, 119, 768])
# x torch.Size([1, 119, 768])
# Training:   1%|▎                                | 3/280 [00:02<03:33,  1.30it/s]embs torch.Size([32, 110, 768])
# features torch.Size([32, 9, 768])
# embs torch.Size([32, 119, 768])
# x torch.Size([1, 119, 768])
# Training:   1%|▍                                | 4/280 [00:03<03:06,  1.48it/s]embs torch.Size([32, 110, 768])
# features torch.Size([32, 9, 768])
# embs torch.Size([32, 119, 768])
# x torch.Size([1, 119, 768])
# Training:   2%|▌                                | 5/280 [00:03<02:51,  1.60it/s]embs torch.Size([32, 110, 768])
# features torch.Size([32, 9, 768])
# embs torch.Size([32, 119, 768])
# x torch.Size([1, 119, 768])
# Training:   2%|▋                                | 6/280 [00:04<02:41,  1.69it/s]embs torch.Size([32, 110, 768])
# features torch.Size([32, 9, 768])
# embs torch.Size([32, 119, 768])
# x torch.Size([1, 119, 768])
# Training:   2%|▊                                | 7/280 [00:04<02:35,  1.75it/s]embs torch.Size([32, 110, 768])
# features torch.Size([32, 9, 768])
# embs torch.Size([32, 119, 768])
# x torch.Size([1, 119, 768])
# Training:   3%|▉                                | 8/280 [00:05<02:32,  1.79it/s]embs torch.Size([32, 110, 768])
# features torch.Size([32, 9, 768])
# embs torch.Size([32, 119, 768])
# x torch.Size([1, 119, 768])
# Training:   3%|█                                | 9/280 [00:05<02:28,  1.82it/s]embs torch.Size([32, 110, 768])
# features torch.Size([32, 9, 768])
# embs torch.Size([32, 119, 768])
# x torch.Size([1, 119, 768])
# Training:   4%|█▏                              | 10/280 [00:06<02:25,  1.85it/s]embs torch.Size([32, 110, 768])
# features torch.Size([32, 9, 768])
# embs torch.Size([32, 119, 768])
# x torch.Size([1, 119, 768])
# ^C
# Training:   4%|█▏                              | 10/280 [00:06<03:05,  1.45it/s]
# Traceback (most recent call last):
#   File "/home/studio-lab-user/sagemaker-studiolab-notebooks/GF-OLD/train_joint.py", line 183, in <module>
#     trainer.train()
#   File "/home/studio-lab-user/sagemaker-studiolab-notebooks/GF-OLD/trainer_joint.py", line 94, in train
#     self.train_one_epoch()
#   File "/home/studio-lab-user/sagemaker-studiolab-notebooks/GF-OLD/trainer_joint.py", line 153, in train_one_epoch
#     _loss.backward()
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torch/_tensor.py", line 487, in backward
#     torch.autograd.backward(
#   File "/home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/torch/autograd/__init__.py", line 197, in backward
#     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# KeyboardInterrupt
